# %%
# Install packages (run this cell only once)
# !pip install -U langchain langchain-community langchain-text-splitters langchain-huggingface faiss-cpu sentence-transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain
#   Using cached langchain-1.2.15-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-community
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-text-splitters
#   Using cached langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Collecting langchain-huggingface
#   Using cached langchain_huggingface-1.2.2-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: faiss-cpu in c:\users\dell\appdata\roaming\python\python312\site-packages (1.13.2)
# Requirement already satisfied: sentence-transformers in c:\users\dell\appdata\roaming\python\python312\site-packages (5.4.1)
# Collecting langchain-core<2.0.0,>=1.2.10 (from langchain)
#   Using cached langchain_core-1.3.2-py3-none-any.whl.metadata (4.4 kB)
# Collecting langgraph<1.2.0,>=1.1.5 (from langchain)
#   Using cached langgraph-1.1.9-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\programdata\anaconda3\lib\site-packages (from langchain) (2.8.2)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community)
#   Using cached langchain_classic-1.0.4-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-community) (2.0.34)
# Collecting requests<3.0.0,>=2.32.5 (from langchain-community)
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\programdata\anaconda3\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-community) (8.2.3)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Using cached pydantic_settings-2.14.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting langsmith<1.0.0,>=0.1.125 (from langchain-community)
#   Using cached langsmith-0.7.36-py3-none-any.whl.metadata (15 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\dell\appdata\roaming\python\python312\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in c:\users\dell\appdata\roaming\python\python312\site-packages (from langchain-huggingface) (1.12.0)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in c:\users\dell\appdata\roaming\python\python312\site-packages (from langchain-huggingface) (0.22.2)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from faiss-cpu) (24.1)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from sentence-transformers) (5.6.2)
# Requirement already satisfied: torch>=1.11.0 in c:\users\dell\appdata\roaming\python\python312\site-packages (from sentence-transformers) (2.11.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\programdata\anaconda3\lib\site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\programdata\anaconda3\lib\site-packages (from sentence-transformers) (4.11.0)
# Requirement already satisfied: tqdm>=4.0.0 in c:\programdata\anaconda3\lib\site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: filelock>=3.10.0 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\users\dell\appdata\roaming\python\python312\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.27.0)
# Requirement already satisfied: typer in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\programdata\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Collecting langchain-protocol>=0.0.10 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Using cached langchain_protocol-0.0.12-py3-none-any.whl.metadata (1.8 kB)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Using cached uuid_utils-0.14.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Using cached langgraph_checkpoint-4.0.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.9 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Using cached langgraph_prebuilt-1.0.11-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Using cached langgraph_sdk-0.3.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading xxhash-3.7.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.1.125->langchain-community)
#   Downloading orjson-3.11.8-cp312-cp312-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.21.0)
# Collecting typing-inspection>=0.4.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain-community)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2025.1.31)
# Requirement already satisfied: joblib>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.0.1)
# Requirement already satisfied: setuptools<82 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\dell\appdata\roaming\python\python312\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.0.0->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\dell\appdata\roaming\python\python312\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.4.4)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\dell\appdata\roaming\python\python312\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: anyio in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.0.2)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\programdata\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (2.1)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading ormsgpack-1.12.2-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.0.0)
# Collecting typing_extensions>=4.5.0 (from sentence-transformers)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\programdata\anaconda3\lib\site-packages (from typer->huggingface-hub<2.0.0,>=0.33.4->langchain-huggingface) (8.1.7)
# Using cached langchain-1.2.15-py3-none-any.whl (112 kB)
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Using cached langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Using cached langchain_huggingface-1.2.2-py3-none-any.whl (31 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Using cached langchain_classic-1.0.4-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-1.3.2-py3-none-any.whl (542 kB)
# Using cached langgraph-1.1.9-py3-none-any.whl (173 kB)
# Using cached langsmith-0.7.36-py3-none-any.whl (381 kB)
# Using cached pydantic_settings-2.14.0-py3-none-any.whl (60 kB)
# Using cached requests-2.33.1-py3-none-any.whl (64 kB)
# Using cached langchain_protocol-0.0.12-py3-none-any.whl (6.6 kB)
# Using cached langgraph_checkpoint-4.0.2-py3-none-any.whl (51 kB)
# Using cached langgraph_prebuilt-1.0.11-py3-none-any.whl (36 kB)
# Using cached langgraph_sdk-0.3.13-py3-none-any.whl (96 kB)
# Using cached marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Downloading orjson-3.11.8-cp312-cp312-win_amd64.whl (127 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached uuid_utils-0.14.1-cp39-abi3-win_amd64.whl (187 kB)
# Downloading xxhash-3.7.0-cp312-cp312-win_amd64.whl (31 kB)
# Downloading ormsgpack-1.12.2-cp312-cp312-win_amd64.whl (117 kB)
# Installing collected packages: xxhash, uuid-utils, typing_extensions, requests, ormsgpack, orjson, marshmallow, httpx-sse, typing-inspection, typing-inspect, langchain-protocol, langgraph-sdk, dataclasses-json, pydantic-settings, langsmith, langchain-core, langgraph-checkpoint, langchain-text-splitters, langchain-huggingface, langgraph-prebuilt, langchain-classic, langgraph, langchain-community, langchain
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.3 langchain-1.2.15 langchain-classic-1.0.4 langchain-community-0.4.1 langchain-core-1.3.2 langchain-huggingface-1.2.2 langchain-protocol-0.0.12 langchain-text-splitters-1.1.2 langgraph-1.1.9 langgraph-checkpoint-4.0.2 langgraph-prebuilt-1.0.11 langgraph-sdk-0.3.13 langsmith-0.7.36 marshmallow-3.26.2 orjson-3.11.8 ormsgpack-1.12.2 pydantic-settings-2.14.0 requests-2.33.1 typing-inspect-0.9.0 typing-inspection-0.4.2 typing_extensions-4.15.0 uuid-utils-0.14.1 xxhash-3.7.0

# %%
# STEP 1: Import required libraries
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

# %%
# STEP 2: Load the text document
file_path = "sample.txt"   # Make sure file is in same folder

loader = TextLoader(file_path, encoding="utf-8")
documents = loader.load()

print("Loaded Documents:", len(documents))
# Out:
# Loaded Documents: 1

# %%
# STEP 3: Split document into chunks
splitter = CharacterTextSplitter(
    separator="\n",
    chunk_size=500,
    chunk_overlap=50
)

split_docs = splitter.split_documents(documents)

print("Total Chunks:", len(split_docs))
# Out:
# Total Chunks: 2

# %%
# STEP 4: Create embeddings using Hugging Face
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
# STEP 5: Store embeddings in FAISS
vectorstore = FAISS.from_documents(
    documents=split_docs,
    embedding=embeddings
)

# %%
# STEP 6: Perform similarity search
query = "What is artificial intelligence?"

results = vectorstore.similarity_search(query, k=3)

# %%
# STEP 7: Display results
for i, doc in enumerate(results, start=1):
    print(f"\nResult {i}")
    print("-" * 50)
    print(doc.page_content)
    print("Metadata:", doc.metadata)
# Out:
# Result 1
# --------------------------------------------------
# Artificial Intelligence (AI) is a branch of computer science that aims to create machines capable of intelligent behavior.
# It involves learning from data, recognizing patterns, and making decisions.
# Machine Learning is a subset of AI that allows systems to learn and improve automatically without being explicitly programmed.
# Deep Learning is a further subset that uses neural networks with many layers.
# Metadata: {'source': 'sample.txt'}
#
# Result 2
# --------------------------------------------------
# AI is widely used in applications such as healthcare, finance, agriculture, and transportation.
# For example, AI can help farmers detect crop diseases, recommend fertilizers, and improve yield.
# Natural Language Processing (NLP) enables machines to understand and generate human language.
# This is used in chatbots, translation systems, and voice assistants.
# In the future, AI is expected to play a major role in automation and decision-making across industries.
# Metadata: {'source': 'sample.txt'}
